# %% [markdown]
# #matplotlib 중급

# %% [markdown]
# # matplolib 중급

# %% [markdown]
# ## 시스템 점검

# %%
import sys

# %%
sys.version
# Out:
# '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]'

# %%
sys.path
# Out:
# ['C:\\2023-A-DA',
#  'C:\\Users\\102\\anaconda3\\python39.zip',
#  'C:\\Users\\102\\anaconda3\\DLLs',
#  'C:\\Users\\102\\anaconda3\\lib',
#  'C:\\Users\\102\\anaconda3',
#  '',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\102\\.ipython']

# %%
    import matplotlib as mpl
    import matplotlib.pyplot as pit
    
    mpl.rc('font', family='Malgun Gothic')
    
    plt.plot([1,2,3,4]. [10, 20, 30, 40])
    plt.title()'plotting')
    plt.show()
# Out:
#   File "C:\Users\102\AppData\Local\Temp\ipykernel_16992\1456268134.py", line 6
#     plt.plot([1,2,3,4]. [10, 20, 30, 40])
#                         ^
# SyntaxError: invalid syntax

# %%
    import matplotlib.pyplot as pit
    
    mpl.rc('font', family='Malgun Gothic')
    
    plt.plot([1,2,3,4]. [10, 20, 30, 40])
    plt.title('plotting')
    plt.show()
# Out:
#   File "C:\Users\102\AppData\Local\Temp\ipykernel_16992\598394239.py", line 5
#     plt.plot([1,2,3,4]. [10, 20, 30, 40])
#                         ^
# SyntaxError: invalid syntax

# %%
    import matplotlib.pyplot as pit
    
    mpl.rc('font', family='Malgun Gothic')
    
    plt.plot([1,2,3,4], [10, 20, 30, 40])
    plt.title('plotting')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16992\698082994.py in <module>
#       1 import matplotlib.pyplot as pit
#       2
# ----> 3 mpl.rc('font', family='Malgun Gothic')
#       4
#       5 plt.plot([1,2,3,4], [10, 20, 30, 40])
#
# NameError: name 'mpl' is not defined

# %%
    import matplotlib.pyplot as pit
    
    mpl.rc('font', family='Malgun Gothic')
    mpl.rc('axes')
    
    plt.plot([1,2,3,4], [10, 20, 30, 40])
    plt.title('plotting')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16992\110919405.py in <module>
#       1 import matplotlib.pyplot as pit
#       2
# ----> 3 mpl.rc('font', family='Malgun Gothic')
#       4 mpl.rc('axes')
#       5
#
# NameError: name 'mpl' is not defined

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='margun Gothic')
plt.plot([-2,-1,0,1,2,3],[20,30,15,40,45,35], label='선 1')
plt.plot([-2,-1,0,1,2,3],[-25,10,35,20,15,25], label='선 2')
plt.title('선 그래프 예제')
plt.xlabel('x축')
plt.ylabel('y축')
plt.legend()
plt.show()
# Out:
# findfont: Font family ['margun Gothic'] not found. Falling back to DejaVu Sans.
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family ['margun Gothic'] not found. Falling back to DejaVu Sans.
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import numpy as np

arrays, bins, patches = plt.hist([1,1,2,3,4,5,6,6,8,10], bins=np.arange(0.5, 11.5), width=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(7,4))
plt.rc('font', family='Margun Gothic')
plt.rcParams['axes.unicode_minus'] = False

x=np.linspace(-2 * np.pi, 2 * np.pi, 200)
plt.plot(x, np.sin(x)*10)
plt.plot(x, x**2)
plt.plot(x, 2 * x**2 - 3*x)

plt.grid(True)
plt.title('다양한 그래프')
plt.show()
# Out:
# findfont: Font family ['Margun Gothic'] not found. Falling back to DejaVu Sans.
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\102\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family ['Margun Gothic'] not found. Falling back to DejaVu Sans.

# %%
arrays
# Out:
# array([2., 1., 1., 1., 1., 2., 0., 1., 0., 1.])

# %%
bins
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5])

# %%
patches
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## random.randint(a,b)

# %%
import random
random.randint(1,6)
# Out:
# 3

# %%
import random
random.randrange(1,6)
# Out:
# 4

# %%
import random as rd

dice=[]
for i in range(5):
    dice.append(rd.randint[1,6])
    
dice
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16992\2420131838.py in <module>
#       3 dice=[]
#       4 for i in range(5):
# ----> 5     dice.append(rd.randint[1,6])
#       6
#       7 dice
#
# TypeError: 'method' object is not subscriptable

# %%
import random as rd

dice=[]
for i in range(5):
    dice.append(rd.randint(1,6))
    
dice
# Out:
# [4, 4, 1, 5, 1]

# %% [markdown]
# ### 리스트 컴프리핸션

# %%
 dice = [rd.randint(1,6) for i in range(10)]
dice
# Out:
# [2, 3, 1, 6, 3, 4, 2, 3, 1, 5]

# %%
rd.choices(range(1,7), k=5)
# Out:
# [5, 5, 6, 3, 6]

# %%
import random
import matplotlib.pyplot as plt

dice = []

for i in range(1000):
    dice.append(random.randint(1,6))
    
plt.hist(dice, bins=np.arange(0.5, 7.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13856\1460496553.py in <module>
#       7     dice.append(random.randint(1,6))
#       8
# ----> 9 plt.hist(dice, bins=np.arange(0.5, 7.5))
#      10 plt.show()
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
import random

result=[]
for i in range(13):
    result.append(random.randint(1, 1000))
    
print(sorted(result))
    
plt.boxplot(result)
plt.show()
# Out:
# [36, 45, 86, 108, 427, 499, 645, 652, 679, 680, 695, 752, 833]

# %%
import sys

# %%
sys.version
# Out:
# '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]'

# %%
sys.path
# Out:
# ['C:\\2023-A-DA',
#  'C:\\Users\\102\\anaconda3\\python39.zip',
#  'C:\\Users\\102\\anaconda3\\DLLs',
#  'C:\\Users\\102\\anaconda3\\lib',
#  'C:\\Users\\102\\anaconda3',
#  '',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\102\\.ipython']

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

dice = []

for i in range(1000):
    dice.append(random.randint(1,6))
    
plt.hist(dice, bins=np.arange(0.5, 7.5))
plt.show()

# %%
import matplotlib.pyploy as plt
improt random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot([result1m result2])
# Out:
#   File "C:\Users\102\AppData\Local\Temp\ipykernel_13856\3851044423.py", line 2
#     improt random
#            ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyploy as plt
improt random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot([result1,result2])
plt.show()
# Out:
#   File "C:\Users\102\AppData\Local\Temp\ipykernel_13856\3767689086.py", line 2
#     improt random
#            ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot([result1,result2])
plt.show()

# %% [markdown]
# # plt.figue(figsize=(m,n))

# %%
import numpy as np
ax1=plt.subplot(2,1,1)
plt.plot(np.random.randint(1, 10, 10),'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
#print(ax1)

ax2=plt.subplot(2,1,2)
plt.plot(np.arange(10), np.arange(10)*2, 'r,-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
#print(ax2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## plt.subplost()

# %%
import matplotlib.pyplot as plt

fig. axes=plt.subplots(2,3)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13856\2005763350.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 fig. axes=plt.subplots(2,3)
#       4
#       5 plt.show()
#
# NameError: name 'fig' is not defined

# %%
import matplotlib.pyplot as plt

fig, axes=plt.subplots(2,2)
plt.figure(figsize=[6,4])

axes[0, 0].plot([1,2,3,4])
axes[0, 0].set_title("Subplot 1")

axes[0, 1].plot([4,3,2,1])
axes[0, 1].set_title("Subplot 2")

axes[1, 0].hist([1,2,2,3,3,3,4,4,4,4],bins=5)
axes[1, 0].set_title("Subplot 3")

axes[1, 1].scatter([1,2,3,4],[4,3,2,1])
axes[1, 1].set_title("Subplot 4")

plt.show()

# %%
plt. subplots(2,3,sharex=True,sharey=True)
plt.show()

# %% [markdown]
# # fig.add_subplot()

# %%
fig=plt.figure(figsize=(10,8))
ax2=fig.add_subplot(2,2,2)
plt.plot(np.random.randn(50).cumsum(),'k--')
ax3=fig.add_subplot(2,2,3)
